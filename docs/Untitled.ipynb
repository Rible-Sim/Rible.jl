# %%
using JSServe, Markdown
Page(exportable=true, offline=true)
# Out:
# Page(Session(Base.RefValue{Union{Nothing, WebSockets.WebSocket, IOBuffer}}(nothing), Dict{String, Tuple{Bool, Observables.Observable}}(), Dict{Symbol, Any}[], Set{JSServe.Asset}(), JSServe.JSCode[], "62ca5e6d-6008-4f0e-88b9-4a3a99305e17", Channel{Bool}(1), JSServe.init_session, JSServe.UrlSerializer(true, nothing, true, "http://localhost:9284", true), Base.RefValue{Union{Nothing, JSServe.JSException}}(nothing), Observable{Union{Nothing, Dict{String, Any}}} with 0 listeners. Value:
# nothing, Observable{Bool} with 0 listeners. Value:
# false, Observables.ObserverFunction[], Dict{String, WeakRef}()), Dict{String, Session}(), true, true)

# %%
using WGLMakie
WGLMakie.activate!()
# Set the default resolution to something that fits the Documenter theme
set_theme!(resolution=(800, 400))
scatter(1:4, color=1:4)
# Out:
# <div id="1f28df62-8c1c-482d-9192-e4d20ab5f189" data-jscall-id="18" style="visibility: hidden;">
#   <div data-jscall-id="11">
#     <canvas data-jscall-id="10" tabindex="0"></canvas>
#   </div>
#   <script data-jscall-id="12" type="text/javascript">
#     window.__define = window.define;
#     window.__require = window.require;
#     window.define = undefined;
#     window.require = undefined;
#
# </script>
#   <script data-jscall-id="13" src="data:text/javascript;base64,..."></script>
#   <script data-jscall-id="14" src="data:text/javascript;base64,..."></script>
#   <script data-jscall-id="15" src="https://unpkg.com/three@0.136.0/build/three.js"></script>
#   <script data-jscall-id="16" type="text/javascript">
#     window.define = window.__define;
#     window.require = window.__require;
#     window.__define = undefined;
#     window.__require = undefined;
#
# </script>
#   <script data-jscall-id="17" type="text/javascript">
# (()=> {
#     JSServe.register_sub_session('1f28df62-8c1c-482d-9192-e4d20ab5f189')
#     const init_data_b64 = '...'
#     JSServe.init_from_b64(init_data_b64)
#     if (!true){
#         JSServe.update_obs('16419669095232050526', true)
#     }
# })()
# </script>
# </div>

# %%
scatter(1:4, color=1:4)
# Out:
# <div id="482a9400-9b58-445a-8b2c-3cdb9a8312cf" data-jscall-id="27" style="visibility: hidden;">
#   <div data-jscall-id="20">
#     <canvas data-jscall-id="19" tabindex="0"></canvas>
#   </div>
#   <script data-jscall-id="21" type="text/javascript">
#     window.__define = window.define;
#     window.__require = window.require;
#     window.define = undefined;
#     window.require = undefined;
#
# </script>
#   <script data-jscall-id="22" src="data:text/javascript;base64,..."></script>
#   <script data-jscall-id="23" src="data:text/javascript;base64,..."></script>
#   <script data-jscall-id="24" src="https://unpkg.com/three@0.136.0/build/three.js"></script>
#   <script data-jscall-id="25" type="text/javascript">
#     window.define = window.__define;
#     window.require = window.__require;
#     window.__define = undefined;
#     window.__require = undefined;
#
# </script>
#   <script data-jscall-id="26" type="text/javascript">
# (()=> {
#     JSServe.register_sub_session('482a9400-9b58-445a-8b2c-3cdb9a8312cf')
#     const init_data_b64 = '...'
#     JSServe.init_from_b64(init_data_b64)
#     if (!true){
#         JSServe.update_obs('7080219710114396416', true)
#     }
# })()
# </script>
# </div>
# ┌ Info: Makie is caching fonts, this may take a while. Needed only on first run!
# └ @ Makie C:\Users\luo22\.julia\packages\Makie\fEZv2\src\utilities\texture_atlas.jl:119

# %%
Page(exportable=true, offline=true)
# Out:
# Page(Session(Base.RefValue{Union{Nothing, WebSockets.WebSocket, IOBuffer}}(nothing), Dict{String, Tuple{Bool, Observable}}(), Dict{Symbol, Any}[], Set{JSServe.Asset}(), JSServe.JSCode[], "3d0cdf39-146c-4612-8914-3aaf8822e463", Channel{Bool}(1), JSServe.init_session, JSServe.UrlSerializer(true, nothing, true, "http://localhost:9284", true), Base.RefValue{Union{Nothing, JSServe.JSException}}(nothing), Observable{Union{Nothing, Dict{String, Any}}} with 0 listeners. Value:
# nothing, Observable{Bool} with 0 listeners. Value:
# false, Observables.ObserverFunction[], Dict{String, WeakRef}()), Dict{String, Session}(), true, true)

# %%
scatter(rand(10))
# Out:
# <div id="f7c68f07-698b-4284-8251-dd572c1feadd" data-jscall-id="51" style="visibility: hidden;">
#   <div data-jscall-id="47">
#     <canvas data-jscall-id="46" tabindex="0"></canvas>
#   </div>
#   <script data-jscall-id="48" type="text/javascript">
#     window.__define = window.define;
#     window.__require = window.require;
#     window.define = undefined;
#     window.require = undefined;
#
# </script>
#   <script data-jscall-id="49" type="text/javascript">
#     window.define = window.__define;
#     window.require = window.__require;
#     window.__define = undefined;
#     window.__require = undefined;
#
# </script>
#   <script data-jscall-id="50" type="text/javascript">
# (()=> {
#     JSServe.register_sub_session('f7c68f07-698b-4284-8251-dd572c1feadd')
#     const init_data_b64 = '...'
#     JSServe.init_from_b64(init_data_b64)
#     if (!true){
#         JSServe.update_obs('2110939685400674789', true)
#     }
# })()
# </script>
# </div>
